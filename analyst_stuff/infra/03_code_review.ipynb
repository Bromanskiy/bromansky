# %%
import requests
import pandas as pd
import datetime
import json
import time
import pymysql
from io import StringIO
from sqlalchemy import create_engine
from share import assasin_beatch

# %%
#program parameters
#time between checking status
TIME_TO_SLEEP = 10
#number of loops to raise error
LOOP_ERROR_N = 50

# %%
#logs api parameters
TOKEN = assasin_beatch.TOKEN
COUNTER_ID = 44147844
START_DATE = '2019-05-01'
END_DATE = '2019-05-02'
SOURCE = 'hits'
API_HOST = 'https://api-metrika.yandex.ru'
API_FIELDS = (
    'ym:pv:counterID',
    'ym:s:visitID',
    'ym:pv:clientID',
    'ym:pv:watchID',
    'ym:pv:dateTime',
    'ym:pv:lastTrafficSource',
    'ym:pv:URL',
    'ym:pv:goalsID')

params = {
    'date1':START_DATE,
    'date2':END_DATE,
    'source':SOURCE,
    'fields':','.join(sorted(API_FIELDS, key=lambda s: s.lower()))
}

# %%
class CreationQueryError(Exception):pass
class LoopingError(Exception):pass

def eval_query(API_HOST,COUNTER_ID,TOKEN,params):

    url = '{host}/management/v1/counter/{counter_id}/logrequests/evaluate'\
        .format(
            host = API_HOST,
            counter_id = COUNTER_ID
        )
    headers = {'Authorization': TOKEN}
    responce = requests.get(url,params=params,headers=headers)
    
    if responce.status_code == 200:
        return json.loads(responce.text)['log_request_evaluation']['possible']
    else:
        return False

def creating_query(API_HOST,COUNTER_ID,TOKEN,params):
    
    url = '{host}/management/v1/counter/{counter_id}/logrequests'\
        .format(host=API_HOST,
                counter_id=COUNTER_ID)
    headers = {'Authorization': TOKEN}
    responce = requests.post(url,params=params,headers=headers)
    
    if (responce.status_code == 200) and json.loads(responce.text)['log_request']:
        return responce
    else:
        raise CreationQueryError(responce.text)

def checking_status(API_HOST,COUNTER_ID,TOKEN,request_id):

    url = '{host}/management/v1/counter/{counter_id}/logrequest/{request_id}' \
        .format(request_id=request_id,
                counter_id=COUNTER_ID,
                host=API_HOST)        
    headers = {'Authorization': TOKEN}
    responce = requests.get(url,params=params,headers=headers)
    if responce.status_code == 200:
        return json.loads(responce.text)['log_request']['status'], responce
    else:
        ValueError(responce.text)

def download(API_HOST,COUNTER_ID,request_id,parts,TOKEN):
    headers = {'Authorization': TOKEN}
    all_dfs = []
    for part in parts:
        part_num = part['part_number']        
        url = '{host}/management/v1/counter/{counter_id}/logrequest/{request_id}/part/{part}/download' \
                .format(
                    host=API_HOST,
                    counter_id=COUNTER_ID,
                    request_id=request_id,
                    part=part_num
                )
        response = requests.get(url,headers=headers)
        df = pd.read_csv(StringIO(response.text),sep='\t')
        all_dfs.append(df)
    return pd.concat(all_dfs)

def main():
    if eval_query(API_HOST,COUNTER_ID,TOKEN,params):
        created_responce = creating_query(API_HOST,COUNTER_ID,TOKEN,params)
        request_id = json.loads(created_responce.text)['log_request']['request_id']
        status, processed_responce = checking_status(API_HOST,COUNTER_ID,TOKEN,request_id)
        print('request_id: {0},checked status: {1}'.format(request_id,status))
        i = 0
        while status == 'created':
            time.sleep(TIME_TO_SLEEP)
            status, processed_responce = checking_status(API_HOST,COUNTER_ID,TOKEN,request_id)
            print('request_id: {0},cur status: {1}'.format(request_id,status))
            i+=1
            if i > LOOP_ERROR_N:
                raise LoopingError('request_id:{0}'.format(request_id))
        parts = json.loads(processed_responce.text)['log_request']['parts']
        df = download(API_HOST,COUNTER_ID,request_id,parts,TOKEN)
        
        for column in API_FIELDS:
            if column.find('date') < 0:
                df[column] = df[column].astype(str)
            else:
                df[column] = pd.to_datetime(df[column])
        return df

# %%
eval_query(API_HOST,COUNTER_ID,TOKEN,params)
# Out:
# True

# %%
resp = creating_query(API_HOST,COUNTER_ID,TOKEN,params)

# %%
request_id = json.loads(resp.text)['log_request']['request_id']

# %%
_, resp = checking_status(API_HOST,COUNTER_ID,TOKEN,request_id)

# %%
resp.text
# Out:
# '{"log_request":{"request_id":5149786,"counter_id":44147844,"source":"hits","date1":"2019-05-01","date2":"2019-05-02","fields":["ym:pv:clientID","ym:pv:counterID","ym:pv:dateTime","ym:pv:goalsID","ym:pv:lastTrafficSource","ym:pv:URL","ym:pv:watchID"],"status":"processed","size":795570,"parts":[{"part_number":0,"size":795570}]}}'

# %%
parts = json.loads(resp.text)['log_request']['parts']

# %%
df = download(API_HOST,COUNTER_ID,request_id,parts,TOKEN)

# %%
df.head()
# Out:
#         ym:pv:clientID  ym:pv:counterID       ym:pv:dateTime ym:pv:goalsID  \
# 0  1556542121847326075         44147844  2019-05-01 15:46:20            []
# 1  1556542121847326075         44147844  2019-05-01 15:46:20            []
# 2  1556542121847326075         44147844  2019-05-01 15:46:35            []
# 3  1556542121847326075         44147844  2019-05-01 15:46:40            []
# 4  1556725401310710672         44147844  2019-05-01 18:42:33            []
#
#   ym:pv:lastTrafficSource                                        ym:pv:URL  \
# 0                  direct                 https://metrica.yandex.com/about
# 1                 organic                 https://metrica.yandex.com/about
# 2                  direct                 https://metrica.yandex.com/about
# 3                external  https://passport.yandex.com/auth?origin=metrica
# 4                  direct              https://metrica.yandex.com.tr/about
#
#          ym:pv:watchID
# 0  2299626911413767664
# 1  2299626893212847600
# 2  2299630949544693132
# 3  2299632174425902446
# 4  2302398464128912828

# %%
df['ym:pv:URL'].unique()
# Out:
# array(['https://metrica.yandex.com/about',
#        'https://passport.yandex.com/auth?origin=metrica',
#        'https://metrica.yandex.com.tr/about',
#        'https://passport.yandex.com.tr/auth?origin=metrica',
#        'goal://metrica.yandex.com.tr/GetCounterMain',
#        'https://metrica.yandex.com/about/',
#        'goal://metrica.yandex.com/GetCounterMain',
#        'https://metrica.yandex.com/about/info/traffic',
#        'https://yandex.com/', 'goal://metrica.yandex.com/GetCounterUP',
#        'goal://metrica.yandex.com/TryDemoMain',
#        'https://metrika.yandex.ru/about',
#        'goal://metrica.yandex.com.tr/TryDemoMain',
#        'https://metrika.yandex.ru/about/info/integrations',
#        'https://metrika.yandex.ru/about/info/pricing',
#        'goal://metrica.yandex.com.tr/GetCounterUP',
#        'https://passport.yandex.com/registration/?mode=register',
#        'https://passport.yandex.com.tr/registration/?mode=register',
#        'https://metrica.yandex.com/about/info/pricing',
#        'goal://metrica.yandex.com/GetCounterInt',
#        'http://extensions.joomla.org/extensions/site-management/analytics/site-analytics-cloud-based/20026',
#        'https://metrica.yandex.com/about/info/gdpr',
#        'https://metrica.yandex.com.tr/about/info/traffic',
#        'https://wordpress.org/plugins/dl-yandex-metrika/',
#        'https://metrica.yandex.ru/add',
#        'goal://metrika.yandex.ru/GetCounterUP',
#        'https://cuadrosmoodpic.com/avengers',
#        'https://redirect.appmetrica.yandex.com/serve/817359381749359774',
#        'https://metrica.yandex.com/about/info/features',
#        'https://metrica.yandex.com/about/info/behavior#sessionreplay',
#        'http://help-ru.tilda.ws/statistic',
#        'https://metrica.yandex.com/about?source=tableau_direct',
#        'https://cuadrosmoodpic.com/product-page/endgame',
#        'https://metrica.yandex.com/about/info/privacy-policy',
#        'https://gomesfilipe.com/about_me',
#        'https://metrica.yandex.com.tr/about/info/pricing',
#        'https://metrica.yandex.com.tr/about/info/features',
#        'https://metrica.yandex.com/about/info/partners',
#        'goal://metrica.yandex.com/Integrations',
#        'https://metrica.yandex.com/about/info/integrations',
#        'https://wordpress.org/plugins/yandex-metrica/',
#        'https://play.google.com/store/apps/details?id=ru.yandex.mobile.metrica',
#        'https://wordpress.org/plugins/yandex-metrika/',
#        'https://yandex.com/support/metrica/troubleshooting/gdpr.html',
#        'goal://metrica.yandex.com/GetinTouchGdpr',
#        'goal://metrica.yandex.com.tr/GetCounterInt',
#        'https://metrica.yandex.com/about/?fbclid=IwAR1t1hYMXP12chdF_pc0MLmOrAvOzGcOzN_I7_5Xy2oO9D_4N3A_nxDAROc',
#        'https://metrica.yandex.com/about/info/performance',
#        'https://metrica.yandex.com.tr/about/info/behavior',
#        'https://chrome.google.com/webstore/detail/яндексметрика/gohkhnlapkabjdchabokoddamjgaejnn?hl=ru',
#        'https://opencart.com/index.php?route=marketplace/extension/info&extension_id=32175&page=1',
#        'https://metrica.yandex.com.tr/about/info/performance',
#        'https://play.google.com/store/apps/details?id=ru.vdmodule.androidmetrix',
#        'https://metrika.yandex.ru/about/info/integrations?from=metrika-help',
#        'https://support.wix.com/en/article/adding-your-yandex-metrica-code-to-your-wix-site',
#        'https://yandex.com/portal/set/lang/?intl=en&sk=yc4a34932d90389d2733dc2bab51c8301',
#        'https://metrica.yandex.com/about/info/reports',
#        'https://yandex.com.tr/portal/set/lang/?intl=en&sk=yb1c980ca26973d7ae464f9e1d3b23be9',
#        'goal://metrica.yandex.com.tr/TryDemoInt',
#        'https://docs.ddmanager.ru/integrations/yandex-metrica',
#        'https://metrica.yandex.com/about/info/behavior#clickheatmaps',
#        'https://yandex.com/legal/metrica_agreement/',
#        'https://cuadrosmoodpic.com/cart',
#        'https://metrica.yandex.com.tr/about/info/audience',
#        'https://gomesfilipe.com/pulse',
#        'https://static.wixstatic.com/media/a634a5_372d916ec354483da00bd834d1374a1c~mv2_d_1476_1476_s_2.png/v1/fill/w_1032,h_1032,al_c,usm_0.66_1.00_0.01/a634a5_372d916ec354483da00bd834d1374a1c~mv2_d_1476_1476_s_2.png',
#        'https://yandex.com/support/metrica/troubleshooting/other-qanda.xml',
#        'goal://metrica.yandex.com/GetinTouch',
#        'https://yandex.com/support/direct/general/yan.xml?lang=en',
#        'https://linkedin.com/showcase/18084001',
#        'https://yandex.com.tr/portal/set/lang/?intl=en&sk=y02d3ed30b73d1e5be67f9e777eda4055',
#        'http://lpgenerator.ru/blog/2014/02/11/kak-podklyuchit-yandeks-metrika-k-celevym-stranicam-lpgenerator/',
#        'https://cuadrosmoodpic.com/avengers?fbclid=IwAR2wiMlBgloSs6ktu89YMB9b8LEZ3pDWFiNct1S3nAhY84hdB5Derxrjink',
#        'https://cuadrosmoodpic.com/product-page/todos-por-el-guantelete',
#        'https://cuadrosmoodpic.com/thank-you-page/e6b6d97a-8ca2-49bd-858d-75c8edc7230d?appSectionParams={}',
#        'https://metrica.yandex.com/about/?fbclid=IwAR3o1K0p3UHalsnTq1mfCCm6f5uuAHGsI0d6Sn_TnViZ0aIOo0ol5lSA2Go',
#        'https://metrica.yandex.com.tr/about#status=ok',
#        'http://marketplace.1c-bitrix.ru/solutions/slam.counters/#tab-about-link',
#        'https://marketplace.1c-bitrix.ru/solutions/intervolga.conversion/',
#        'https://static.wixstatic.com/media/a634a5_11a8146e1f59451f884838a9653bb844~mv2_d_1476_1476_s_2.png/v1/fill/w_1032,h_1032,al_c,usm_0.66_1.00_0.01/a634a5_11a8146e1f59451f884838a9653bb844~mv2_d_1476_1476_s_2.png',
#        'https://marketplace.1c-bitrix.ru/solutions/asd.ordertracking/',
#        'https://metrica.yandex.com/about/info/behavior',
#        'https://metrica.yandex.com/about/?fbclid=IwAR3kkZC7_qsXEq3iMcl9AmmEi4hVtcmG4OO6ZJc89VDP6m76MiprrsxD9Tk',
#        'https://metrica.yandex.com/about?ref=producthunt',
#        'https://metrika.yandex.ru/about/info/integrations?from=doc',
#        'https://redirect.appmetrica.yandex.com/serve/673244192549431327',
#        'https://metrika.yandex.ru/about/info/features',
#        'https://crm-onebox.com/ru/integration-with-yandex-metrika/',
#        'https://cuadrosmoodpic.com/',
#        'https://tech.yandex.com.tr/metrika/',
#        'goal://metrica.yandex.com.tr/Integrations',
#        'https://metrica.yandex.com.tr/about/info/integrations',
#        'goal://metrica.yandex.com/TryDemoInt',
#        'https://cuadrosmoodpic.com/shop',
#        'https://github.com/yandex-money/yandex-money-cms-shopscript5',
#        'https://yandex.com.tr/', 'https://cuadrosmoodpic.com/catalogo-1',
#        'https://cuadrosmoodpic.com/product-page/fin-del-juego-portada',
#        'https://yandex.com.tr/portal/set/lang/?intl=en&sk=y89b1868fbb50a7f180e863d965337ef5',
#        'https://yandex.com.tr/portal/set/lang/?intl=tr&sk=y89b1868fbb50a7f180e863d965337ef5',
#        'https://metrica.yandex.com/about/info/integrations?from=metrika-help',
#        'https://itunes.apple.com/ru/app/webmetrica/id1207892083?mt=8',
#        'https://itunes.apple.com/app/yandex.metrica/id1148059310?l=ru&mt=8',
#        'https://yandex.ru/', 'https://yandex.com/blog/metrica',
#        'https://clickhouse.yandex/',
#        'https://cuadrosmoodpic.com/avengers?fbclid=IwAR321_5Gq_QKg1x921h-RzxgeCI_d7QR_QY1dnWDtejoDdqoc_8-d961QP0',
#        'https://help.leadback.ru/knowledgebase/интеграция-с-яндекс-метрикой/',
#        'https://support.livetex.ru/hc/ru/articles/205133351-Установка-и-настройка-счетчиков-Яндекс-и-Google',
#        'https://netroxsc.ru/system/features/integration/google-analytics-yandex-metrika/',
#        'https://smartis.bi/faq/otlozhiennyie-konviersii-dlia-yandex-metrika-iz-smartcallback/',
#        'https://cuadrosmoodpic.com/product-page/avengers-endgame',
#        'https://static.wixstatic.com/media/a634a5_de4de8f22ac44b39b350cecd8bec650d~mv2_d_1476_1476_s_2.png/v1/fill/w_1032,h_1032,al_c,q_85,usm_0.66_1.00_0.01/a634a5_de4de8f22ac44b39b350cecd8bec650d~mv2_d_1476_1476_s_2.webp',
#        'http://optima-scan.ru/',
#        'http://optima-scan.ru/o-kompanii/kontakty.html',
#        'https://tech.yandex.com/metrika/',
#        'https://umi-cms.ru/product/system/yandexintegration/#ymetrika',
#        'https://metrika.yandex.ru/about/info/performance',
#        'https://metrica.yandex.ru/dashboard?id=44147844',
#        'goal://metrika.yandex.ru/TryDemoInt',
#        'https://metrica.yandex.com/about/?fbclid=IwAR0x4ZjYuKTgyPkx5sw4RwH36DfvbzyH2uEkBf2LjsMwhkWeBqUN1BV0qdI',
#        'https://yandex.com/support/metrica/troubleshooting.xml',
#        'goal://metrica.yandex.com/Support',
#        'https://metrica.yandex.com.tr/about?fbclid=IwAR3RjJV0uDZJ8YMzyTsynqsJTRuT5oqwMXMo91mVXelCAa1d50mj3lpIjN4',
#        'https://metrica.yandex.com/about/info/audience',
#        'https://advantshop.net/help/pages/yandex-metrika',
#        'https://itunes.apple.com/app/yandex.metrica/id1148059310?l=en&mt=8',
#        'https://appmetrica.yandex.com.tr/',
#        'https://radar.metrika.yandex/', 'https://yandex.com/company/',
#        'goal://metrika.yandex.ru/GetCounterInt',
#        'goal://metrica.yandex.com.tr/GetinTouch',
#        'https://yandex.com.tr/support/metrica/troubleshooting/other-qanda.xml',
#        'https://metrica.yandex.com.tr/about/info/behavior#sessionreplay',
#        'https://metrika.yandex.ru/about/info/partners',
#        'goal://metrika.yandex.ru/GetCounterMain',
#        'https://yandex.com/portal/set/lang/?intl=tr&sk=y824db9c5d8a2a80f4cc17ae55a999c47',
#        'https://yandex.com/portal/set/lang/?intl=en&sk=y824db9c5d8a2a80f4cc17ae55a999c47',
#        'https://metrica.yandex.com.tr/about?from=dirface14',
#        'https://metrica.yandex.com/about?fbclid=IwAR2j-zOvkQRNL4H1gz8V1P4GM5rAwgSYlXuilD2CFxC9rvKbFKrQepBFhek',
#        'https://cuadrosmoodpic.com/product-page/gemas-del-infinito',
#        'https://metrica.yandex.com.tr/about?from=direct-help',
#        'https://yandex.com.tr/support/metrica/',
#        'http://metrica.yandex.com/about',
#        'https://metrika.yandex.ru/about/info/traffic',
#        'https://ecwid.com/apps/free/ya-metrika',
#        'https://yandex.com/legal/privacy/',
#        'https://metrica.yandex.com/about/info/performance#customeventstracking',
#        'https://yandex.ru/blog/metrika',
#        'https://yandex.com/portal/set/lang/?intl=en&sk=y9641aeed7a323e0ac2181d15024cab58',
#        'https://yandex.ru/support/metrica/troubleshooting/other-qanda.html',
#        'https://yandex.ru/support/metrika/',
#        'https://play.google.com/store/apps/details?id=analytics.ya',
#        'https://play.google.com/store/apps/details?id=com.redgears.appmetrica&hl=ru',
#        'https://yandex.com/support/metrica/',
#        'https://yandex.ru/support/metrika/troubleshooting/other-qanda.xml',
#        'goal://metrika.yandex.ru/GetinTouch',
#        'https://metrika.yandex.ru/about/info/become-a-partner',
#        'https://drupal.org/project/yandex_metrics',
#        'https://crm-onebox.com/integration-with-yandex-metrika/',
#        'https://github.com/mygento/metrika',
#        'https://jivosite.ru/help/integrations/otslezhyvanye_sobytyi_y_konversyi_jivosite_v_google_analytics_y_yandeks_metryke.html#yandex-metrika',
#        'https://yandex.com/portal/set/lang/?intl=en&sk=ydf3370c578ef55581dcf4ad85db38d8b',
#        'https://metrica.yandex.com/about/info/data-policy/',
#        'https://metrika.yandex.ru/about/info/audience#adblockersusage',
#        'https://metrica.yandex.com/about/?fbclid=IwAR3QPh0NUAjfp7eDQdgeokvsWGNicD74fPAUyxioiCpPqN3kGtNAs_VC-K4',
#        'https://metrica.yandex.com/about?from=dirface14',
#        'https://metrica.yandex.com.tr/about/info/data-policy/',
#        'https://github.com/yandex-money/yandex-money-ycms-v2-prestashop'],
#       dtype=object)

# %%
df[df['ym:pv:URL'] == 'goal://metrika.yandex.ru/TryDemoInt']
# Out:
#            ym:pv:clientID  ym:pv:counterID       ym:pv:dateTime ym:pv:goalsID  \
# 3092  1556793583224488891         44147844  2019-05-02 13:39:55            []
# 6294  1556749098335684271         44147844  2019-05-02 01:28:28            []
#
#      ym:pv:lastTrafficSource                            ym:pv:URL  \
# 3092                internal  goal://metrika.yandex.ru/TryDemoInt
# 6294                internal  goal://metrika.yandex.ru/TryDemoInt
#
#             ym:pv:watchID
# 3092  2320287662191611254
# 6294  2308783151959182757

# %%
df['ym:pv:goalsID'].unique()
# Out:
# array(['[]', '[41646742]', '[30606889]'], dtype=object)

# %%
df[df['ym:pv:goalsID'] == '[41646742]']
# Out:
#            ym:pv:clientID  ym:pv:counterID       ym:pv:dateTime ym:pv:goalsID  \
# 34    1556696203810958790         44147844  2019-05-01 10:36:49    [41646742]
# 47     152693307862964988         44147844  2019-05-01 20:08:39    [41646742]
# 58    1556708190563429717         44147844  2019-05-01 13:56:57    [41646742]
# 89    1556716647740848767         44147844  2019-05-01 16:17:30    [41646742]
# 113   1556718713732268464         44147844  2019-05-01 16:52:06    [41646742]
# ...                   ...              ...                  ...           ...
# 6332  1556796797921691965         44147844  2019-05-02 14:33:23    [41646742]
# 6431  1556781659612469643         44147844  2019-05-02 10:21:01    [41646742]
# 6475  1556572772347950369         44147844  2019-05-02 19:42:48    [41646742]
# 6523  1556781878890737662         44147844  2019-05-02 10:24:53    [41646742]
# 6621  1543856750419221836         44147844  2019-05-02 21:00:59    [41646742]
#
#      ym:pv:lastTrafficSource                                 ym:pv:URL  \
# 34                  internal     goal://metrica.yandex.com/TryDemoMain
# 47                  internal  goal://metrica.yandex.com.tr/TryDemoMain
# 58                  internal     goal://metrica.yandex.com/TryDemoMain
# 89                  internal  goal://metrica.yandex.com.tr/TryDemoMain
# 113                 internal     goal://metrica.yandex.com/TryDemoMain
# ...                      ...                                       ...
# 6332                internal     goal://metrica.yandex.com/TryDemoMain
# 6431                internal     goal://metrica.yandex.com/TryDemoMain
# 6475                internal     goal://metrica.yandex.com/TryDemoMain
# 6523                internal  goal://metrica.yandex.com.tr/TryDemoMain
# 6621                internal  goal://metrica.yandex.com.tr/TryDemoMain
#
#             ym:pv:watchID
# 34    2294758517972077932
# 47    2303752923696270680
# 58    2297906562435059032
# 89    2300117043842059710
# 113   2300661283645754874
# ...                   ...
# 6332  2321128691744574848
# 6431  2317159243952885232
# 6475  2325995441666592160
# 6523  2317220281752161716
# 6621  2327225233600351586
#
# [92 rows x 7 columns]

# %%
df = main()
# Out:
# request_id: 3670021,checked status: created
# request_id: 3670021,cur status: created
# request_id: 3670021,cur status: created
# request_id: 3670021,cur status: created
# request_id: 3670021,cur status: created
# request_id: 3670021,cur status: processed
